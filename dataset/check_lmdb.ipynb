# %%
import lmdb
import pickle
from PIL import Image
import io
from matplotlib import pyplot as plt
import numpy as np
import time

# %%
env = lmdb.open("/data2/yztian/MTedIIMT/subset_en_cs_lmdb/train", readonly=True)

# %%
with env.begin() as txn:
    keys = list(txn.cursor().iternext(values=False))

# %%
len(keys)
# Out:
# 848894

# %%
with env.begin(write=False) as txn:
    value = txn.get(keys[12345])
    data = pickle.loads(value)

# %%
i = Image.frombytes(data["src_img_mode"], data["src_img_size"], data["src_img"])
plt.imshow(i)

# %%
i = Image.frombytes(data["tgt_img_mode"], data["tgt_img_size"], data["tgt_img"])
plt.imshow(i)

# %%
i = Image.frombytes(data["background_mode"], data["background_size"], data["background"])
plt.imshow(i)

# %%
i = Image.frombytes(data["tgt_textimg_mode"], data["tgt_textimg_size"], data["tgt_textimg"])
plt.imshow(i)

# %%
print(data["src_text"].decode())
print(data["tgt_text"].decode())
# Out:
# It's what the woman said to herself.
# Ona si to ta žena řekla sama sobě.
